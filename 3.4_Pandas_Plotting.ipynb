# %% [markdown]
# # Plottare con Pandas

# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  


dataset = load_dataset("yiqing111/Engineering_Jobs_Insight_Dataset")
df = dataset['train'].to_pandas()
df.columns = df.columns.str.replace(' ', '_')
df['Date_Posted'] = pd.to_datetime(df['Date_Posted'], errors='coerce')
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Repo card metadata block was not found. Setting CardData to empty.

# %% [markdown]
# È possibile creare grafici anche utilizzando Pandas. Anche se è più comune usare una libreria dedicata come Matplotlib, Pandas può essere utilizzato per creare grafici. Questo è utile soprattutto per creare velocemente un grafico durante un’analisi.
#
# Non ci concentreremo su questo durante il corso, ma è disponibile se vuoi esplorarlo.
#
# Puoi approfondire l’argomento [qui](https://pandas.pydata.org/docs/user_guide/visualization.html).
#
# ## Tracciare una Series

# %%
job_counts = df['Job_Title'].value_counts()
job_counts = job_counts.head(6)
job_counts
# Out:
# Job_Title
# Software Engineer                                                         311
# Product Manager  Social app startup                                       282
# Associate Product Manager  Social app startup                             277
# 2025 Virtual Summer Intern Program - Product Analyst Intern (Xome)        267
# Real-Time Software Engineer                                               266
# Data Science Internship (Remote Eligible) - Graduate Student Preferred    255
# Name: count, dtype: int64

# %%
plt.figure(figsize=(5, 3))  # imposta una dimensione più compatta
job_counts.plot(kind='bar')
plt.xlabel('')
plt.ylabel('Count of Postings')
plt.title('Job Postings by Job Title')
plt.xticks(rotation=45, ha='right') 
plt.show()

# %% [markdown]
# ## Plotting Dataframes

# %%
df.plot(x='Date_Posted', y='Salary_Min', kind='line')
# Out:
# <Axes: xlabel='Date_Posted'>

# %% [markdown]
# Il problema con i DataFrame (soprattutto quelli di grandi dimensioni) è che i dati potrebbero comunque aver bisogno di essere ripuliti.

# %%
# sort index by job posted date 
df = df.set_index('Date_Posted')   # li ordiniamo rispetto alle date
df.sort_index(inplace=True)
df.head()
# Out:
#                                                                    Job_Title  \
# Date_Posted
# 2019-06-19 06:37:08+00:00                                    DevOps Engineer
# 2019-06-19 06:37:08+00:00                  CryptoCurrency- Software Engineer
# 2019-06-19 06:37:14+00:00                          Backend Software Engineer
# 2019-08-19 12:37:21+00:00  Embedded Software Engineer – Sensors – Electri...
# 2019-11-02 10:55:02+00:00                    Business Analyst in New York eg
#
#                                            Company  \
# Date_Posted
# 2019-06-19 06:37:08+00:00  Roy Talman & Associates
# 2019-06-19 06:37:08+00:00  Roy Talman & Associates
# 2019-06-19 06:37:14+00:00  Roy Talman & Associates
# 2019-08-19 12:37:21+00:00                   Avanti
# 2019-11-02 10:55:02+00:00           ESR Healthcare
#
#                                                                  Description  \
# Date_Posted
# 2019-06-19 06:37:08+00:00  We are looking for a DevOps Engineer for our C...
# 2019-06-19 06:37:08+00:00  Rapidly growing proprietary international trad...
# 2019-06-19 06:37:14+00:00  We are actively looking for a creative, talent...
# 2019-08-19 12:37:21+00:00  Why is This a Great Opportunity? We are lookin...
# 2019-11-02 10:55:02+00:00  Business Analyst in New York eg New York, NY J...
#
#                                           Location  Salary_Min  Salary_Max  \
# Date_Posted
# 2019-06-19 06:37:08+00:00       West Loop, Chicago   138781.27   138781.27
# 2019-06-19 06:37:08+00:00       West Loop, Chicago   117745.63   117745.63
# 2019-06-19 06:37:14+00:00  Westmont, DuPage County   113766.23   113766.23
# 2019-08-19 12:37:21+00:00                       US   110000.00   120000.00
# 2019-11-02 10:55:02+00:00  New York City, New York    70637.84    70637.84
#
#                                                                          URL
# Date_Posted
# 2019-06-19 06:37:08+00:00  https://www.adzuna.com/details/1184897934?utm_...
# 2019-06-19 06:37:08+00:00  https://www.adzuna.com/details/1184897942?utm_...
# 2019-06-19 06:37:14+00:00  https://www.adzuna.com/details/1184898539?utm_...
# 2019-08-19 12:37:21+00:00  https://www.adzuna.com/details/1239116098?utm_...
# 2019-11-02 10:55:02+00:00  https://www.adzuna.com/details/1322665486?utm_...

# %%
df.plot(y='Salary_Min', kind='line')
# Out:
# <Axes: xlabel='Date_Posted'>

# %%
df = df[df['Salary_Min'] > 100]    # salario minimo di almeno un certo valore
df.plot(y='Salary_Min', kind='line')
# Out:
# <Axes: xlabel='Date_Posted'>
